# %%
import pandas as pd
from urllib.request import urlopen
import json
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import csv
import requests
from bs4 import BeautifulSoup
import numpy as np
import googleCreds
from geopy.geocoders import Nominatim, GoogleV3, Bing
from shapely.geometry import Point, shape

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
def getAccommodationDF(minPrice = 500, maxPrice = 2000, maxPages = 1, dfPath = "", savePickle = True):

    """
    The function returns a dataframe with following features:
    - Accommodation id (id): str
    - Accommodation type (type): str
    - Accommodation address (address): str
    - Accommodation price (price): float
    - Coordinates of an accommodation as a list [latitude, longitude] (coords): list of floats

    The data is scrapped from: https://www.immobiliare.it/

    Inputs:

    minPrice    (float): minimum price (rent),
                default: 500

    maxPrice    (float): maxmum price (rent),
                default: 5000

    maxPages    (float): number of result pages to be processed (50 items per page),
                default: 10

    dfPath      (str):  path to save dataframes as pickle files,
                default: "static/miluogo/data/"

    savePickle  (bool): True, if pickle files should be saved to dfPath,
          default: True

    Outputs:

    pandas DataFrame
    """

    urlList = [f"https://www.immobiliare.it/affitto-case/milano/?criterio=rilevanza&prezzoMinimo={minPrice}&prezzoMassimo={maxPrice}"]
    urlList+=[f"https://www.immobiliare.it/affitto-case/milano/?criterio=rilevanza&prezzoMinimo={minPrice}&prezzoMassimo={maxPrice}&pag={i+1}" for i in range(maxPages)]

    objects = {"id":[],
               "type":[],
               "address":[],
               "price":[]}

    for url in urlList:
        session = requests.session()
        response = session.get(url)

        soup = BeautifulSoup(response.text, 'html.parser')
        #print(soup)
        print(soup.find_all('a', class_='Card_in-card__title__234gH'))
        print(soup.find_all('a', class_='Card_in-card__title__234gH')[0])
        input()
        for element in soup.find_all('p', class_='titolo text-primary'):
            try:
                name = element.text.strip().split()
                objects["id"].append(element.find('a').get("id"))
                objects["type"].append(name[0])
                objects["address"].append(" ".join(name[1:]))
            except:
                pass

        for element in soup.find_all('li', class_='lif__item lif__pricing'):
            try:
                if element.find('div')==None:

                    price = element.text.strip().split()[1]
                    price= price.replace(".","")
                    objects["price"].append(int(price))
                else:

                    price = element.find('div').text.strip().split()[1]
                    price= price.replace(".","")

                    objects["price"].append(int(price))
            except:
                pass

            #Sanity check
    assert len(objects["id"]) == len(objects["type"]) == len(objects["address"]) == len(objects["price"])
    print(f"All successful. {len(objects['id'])} objects has been added")

    dfObjects = pd.DataFrame(objects)
    dfObjects["coords"] = dfObjects["address"].map(getLoc)
    dfObjects.dropna(inplace = True)
    if savePickle:
        dfObjects.to_pickle(dfPath+'dfAccommodationsExpanded.pkl')
    return dfObjects

# %%
minPrice=100
maxPrice=2000
maxPages=3
urlList = [f"https://www.immobiliare.it/affitto-case/milano/?criterio=rilevanza&prezzoMinimo={minPrice}&prezzoMassimo={maxPrice}"]
#urlList+=[f"https://www.immobiliare.it/affitto-case/milano/?criterio=rilevanza&prezzoMinimo={minPrice}&prezzoMassimo={maxPrice}&pag={i+1}" for i in range(maxPages)]

objects = {"id":[],
           "type":[],
           "address":[],
           "price":[]}

for url in urlList:
    session = requests.session()
    response = session.get(url)

    soup = BeautifulSoup(response.text, 'html.parser')

    for element in zip(soup.find_all('a', class_='Card_in-card__title__234gH'),soup.find_all('li', class_="Features_nd-list__item__3hWVx Features_in-feat__item__2-hIE Features_in-feat__item--main__3EFFl RealEstateListCard_in-realEstateListCard__features--main__2uSci")):
        print(element[0]['href'].split("/")[-2])
        print(element[0]['title'].split()[0])
        print(' '.join(element[0]['title'].split()[1:]))
        print(int(element[1].text.split("/")[0].split()[1].replace('.','')))
# Out:
# 80901971
# Trilocale
# via Col Moschin 7, Corso San Gottardo, Milano
# 1350
# 84095940
# Bilocale
# via PAOLO DA CANNOBIO 37, Missori, Milano
# 1290
# 89279357
# Bilocale
# via SOLFERINO 11, Lanza, Milano
# 1458
# 89512713
# Bilocale
# via WASHINGTON 71, Washington, Milano
# 950
# 88109391
# Trilocale
# via RAMAZZINI 11, Morgagni, Milano
# 1875
# 89494519
# Quadrilocale
# via Salvio Giuliano 4, Washington, Milano
# 1450
# 89162681
# Bilocale
# via SPARTACO 11, Montenero, Milano
# 1250
# 88083511
# Trilocale
# via SALVIO GIULIANO 4, Washington, Milano
# 1190
# 81732252
# Bilocale
# via Giovanni Battista Piranesi 43, Porta Vittoria, Milano
# 970
# 89294681
# Bilocale
# corso di Porta Nuova 52, Porta Nuova, Milano
# 1085
# 89490517
# Trilocale
# piazza Greco 10, Greco - Segnano, Milano
# 940
# 88752273
# Bilocale
# via Melchiorre Gioia 41, Melchiorre Gioia, Milano
# 800
# 85234687
# Trilocale
# via Francesco Londonio 20-A, Paolo Sarpi, Milano
# 2000
# 88505289
# Trilocale
# via Pinamonte da Vimercate, Moscova, Milano
# 1900
# 87694184
# Bilocale
# via Sofonisba Anguissola 26, Gambara, Milano
# 700
# 89155463
# Bilocale
# via Luigi Boccherini 12, Città Studi, Milano
# 1000
# 79243623
# Bilocale
# via Livigno, Dergano, Milano
# 680
# 83619251
# Monolocale
# Monte Cristallo 1, Zara, Milano
# 700
# 75637106
# Trilocale
# via Lodovico il Moro 125, Tre Castelli - Faenza, Milano
# 1250
# 88656863
# Bilocale
# via Empedocle 16, Villa San Giovanni, Milano
# 820
# 82247676
# Loft
# via Louis Pasteur 16, Pasteur, Milano
# 750
# 88801267
# Bilocale
# via dei Valtorta 6, Turro, Milano
# 900
# 86763532
# Trilocale
# via Montepulciano, Centrale, Milano
# 1800
# 89245855
# Bilocale
# piazza Insubria 12, Martini - Insubria, Milano
# 1000
# 89513763
# Bilocale
# via Adeodato Ressi 9, Maggiolina, Milano
# 850

# %%
def getZone(loc, js='data/zonedecentramento.geojson'):
    point = Point(min(loc), max(loc))
    with open(js) as f:
        js = json.load(f)
    # check each polygon to see if it contains the point
    for feature in js['features']:
        polygon = shape(feature['geometry'])
        if polygon.contains(point):
            return feature["properties"]['ZONADEC']

# %%
df = pd.read_pickle('data/dfAccommodationsExpanded.pkl')
df
# Out:
#                   id          type  \
# 0   link_ad_85188979      Bilocale
# 1   link_ad_63453592        Attico
# 2   link_ad_86792470      Bilocale
# 3   link_ad_86886580  Quadrilocale
# 4   link_ad_85281355     Trilocale
# 5   link_ad_82383218      Bilocale
# 6   link_ad_75892020  Appartamento
# 7   link_ad_86186172  Appartamento
# 8   link_ad_86197160     Trilocale
# 9   link_ad_86638504        Attico
# 10  link_ad_84406582         Villa
# 11  link_ad_85575130      Bilocale
# 12  link_ad_82947181      Bilocale
# 13  link_ad_85980992     Trilocale
# 14  link_ad_86309250      Bilocale
# 15  link_ad_79592117      Bilocale
# 16  link_ad_86433722     Trilocale
# 17  link_ad_87013428     Trilocale
# 18  link_ad_67133679      Bilocale
# 19  link_ad_85035204     Trilocale
# 20  link_ad_86725386     Trilocale
# 21  link_ad_53346343      Bilocale
# 22  link_ad_85003496      Bilocale
# 23  link_ad_80243683  Appartamento
# 24  link_ad_84956962     Trilocale
# 25  link_ad_87052698    Monolocale
# 26  link_ad_87052168  Quadrilocale
# 27  link_ad_87045092      Bilocale
# 28  link_ad_87045088      Bilocale
# 29  link_ad_87052446     Trilocale
# 30  link_ad_87052620     Trilocale
# 31  link_ad_87051670      Bilocale
# 32  link_ad_87045124    Monolocale
# 33  link_ad_87051600    Monolocale
# 34  link_ad_87052450      Bilocale
# 35  link_ad_87051650     Trilocale
# 36  link_ad_87052460     Trilocale
# 37  link_ad_87045094      Bilocale
# 38  link_ad_87045116      Bilocale
# 39  link_ad_87050632      Bilocale
# 40  link_ad_87052444      Bilocale
# 41  link_ad_87045096      Bilocale
# 42  link_ad_87045118     Trilocale
# 43  link_ad_87045126    Monolocale
# 44  link_ad_87045108    Monolocale
# 45  link_ad_87045122    Monolocale
# 46  link_ad_87045100    Monolocale
# 47  link_ad_87045120      Bilocale
# 48  link_ad_87045104      Bilocale
# 49  link_ad_87045106    Monolocale
#
#                                               address  price  \
# 0                  via Cozzi, Greco - Segnano, Milano    900
# 1   via Piero Maroncelli 5, Garibaldi - Corso Como...   2900
# 2               via Louis Pasteur 16, Pasteur, Milano    780
# 3      via Borgogna, Borgogna - Largo Augusto, Milano   4000
# 4                      via Elba 5, Washington, Milano   1900
# 5    piazza Santa Maria Beltrade 1, Carrobbio, Milano   1700
# 6                via Motta, Vercelli - Wagner, Milano   4000
# 7           via Giulio Uberti 9, Indipendenza, Milano   2916
# 8             via Amedeo Modigliani 4, Solari, Milano   1750
# 9          corso San Gottardo, Ascanio Sforza, Milano   2000
# 10  bifamiliare via Giuseppe Martucci 8, Maggiolin...   3500
# 11               via Enrico Cosenz 54, Bovisa, Milano    800
# 12                    ottimo stato, 11, Duomo, Milano   2400
# 13       corso Magenta 24, Cadorna - Castello, Milano   2000
# 14  via Altaguardia 11, Porta Romana - Medaglie d'...   1600
# 15         via Gaetano Donizetti 46, Palestro, Milano   2500
# 16             via San Maurilio 13, Carrobbio, Milano   2500
# 17       via Giacomo Leopardi, Vincenzo Monti, Milano   2083
# 18                   via Rimini 30, Famagosta, Milano   1100
# 19         via Vincenzo Monti, Vincenzo Monti, Milano   2585
# 20            via Francesco Redi 28, Morgagni, Milano   2450
# 21       corso Como 9, Garibaldi - Corso Como, Milano   1250
# 22       corso Como 9, Garibaldi - Corso Como, Milano   1500
# 23  piazzale Principessa Clotilde 8, Porta Nuova, ...   3900
# 24                corso Monforte 36, Palestro, Milano   2700
# 25      via Angelo Michele Grancini 6, Pagano, Milano    710
# 26       via Giuseppe Meda 16, Ascanio Sforza, Milano   2200
# 27                viale Lunigiana 7, Centrale, Milano   1200
# 28  via Francesco Brioschi 65, Pezzotti - Meda, Mi...    850
# 29      via Giorgio Washington 51, Washington, Milano   1100
# 30         corso Concordia, Piave - Tricolore, Milano   2000
# 31   via Pigello Portinari 2, Greco - Segnano, Milano    750
# 32  via Evangelista Torricelli 9, Ascanio Sforza, ...    750
# 33   via Pigello Portinari 2, Greco - Segnano, Milano    500
# 34           via Giuseppe Allegranza 7, Dezza, Milano   1100
# 35            piazza Virgilio, Vincenzo Monti, Milano   1490
# 36             via Marcello Pucci 6, Sempione, Milano   1100
# 37                     via Tortona 28, Solari, Milano   1000
# 38  via Coluccio Salutati 15, Vercelli - Wagner, M...   1000
# 39        via Lomellina 47, Argonne - Corsica, Milano   1000
# 40      via Giorgio Washington 51, Washington, Milano    700
# 41        via Gentilino 9, Corso San Gottardo, Milano    850
# 42             via Sem Benelli 8, Gallaratese, Milano   1500
# 43  via Giovanni Rasori 14, Vercelli - Wagner, Milano    840
# 44  via Giovanni Rasori 14, Vercelli - Wagner, Milano    840
# 45  via Giovanni Rasori 14, Vercelli - Wagner, Milano    740
# 46  via Giovanni Rasori 14, Vercelli - Wagner, Milano    740
# 47              via San Maurilio 1, Carrobbio, Milano   1100
# 48  via Stadera 18, Cermenate - Abbiategrasso, Milano    600
# 49            via Rombon 33, Quartiere Feltre, Milano   1155
#
#                                     coords  contamination  \
# 0                  [45.5092767, 9.2099263]       0.333668
# 1                   [45.4828706, 9.183481]       0.295380
# 2                  [45.4902223, 9.2193974]       0.092183
# 3                  [45.4636501, 9.1990135]       0.413717
# 4                  [45.4656953, 9.1562597]       0.140285
# 5          [45.4628843, 9.186818599999999]       0.355223
# 6                   [45.468491, 9.1552276]       0.151161
# 7                  [45.4696682, 9.2158532]       0.354462
# 8                  [45.4562768, 9.1586758]       0.160098
# 9                     [45.44644, 9.177026]       0.526330
# 10                  [45.495148, 9.1980762]       0.305430
# 11                 [45.5072367, 9.1622713]       1.000000
# 12                 [45.4643653, 9.1885593]       0.348035
# 13         [45.4662662, 9.177747799999999]       0.273929
# 14                 [45.4495176, 9.2001317]       0.753916
# 15                 [45.4669698, 9.2048192]       0.380937
# 16  [45.46197739999999, 9.184002699999999]       0.347208
# 17                   [45.468454, 9.172716]       0.242875
# 18          [45.44085219999999, 9.1703969]       0.541998
# 19                 [45.4710942, 9.1690085]       0.231202
# 20         [45.4767112, 9.213714099999999]       0.239330
# 21                 [45.4818759, 9.1871335]       0.279822
# 22                 [45.4818759, 9.1871335]       0.279822
# 23                 [45.4798228, 9.1933943]       0.261174
# 24          [45.471425, 9.201948999999999]       0.310132
# 25                  [45.471999, 9.1609515]       0.206344
# 26                 [45.4444426, 9.1788793]       0.599689
# 27                  [45.4910839, 9.205669]       0.209911
# 28         [45.4412943, 9.183195999999999]       0.752318
# 29                 [45.4613315, 9.1552382]       0.117827
# 30         [45.4678939, 9.207147299999999]       0.371654
# 31                  [45.502607, 9.2101814]       0.238703
# 32           [45.44455, 9.176829999999999]       0.565142
# 33                  [45.502607, 9.2101814]       0.238703
# 34         [45.4586115, 9.159839999999999]       0.164283
# 35                 [45.4675662, 9.1736272]       0.248325
# 36                 [45.4782924, 9.1668712]       0.277132
# 37                 [45.4551585, 9.1614421]       0.198157
# 38                 [45.4631496, 9.1593704]       0.156212
# 39                 [45.4625691, 9.2306147]       0.576748
# 40                 [45.4613315, 9.1552382]       0.117827
# 41                 [45.4490901, 9.1810181]       0.526122
# 42                 [45.4967547, 9.1244444]       0.907067
# 43         [45.4678875, 9.161910299999999]       0.186135
# 44         [45.4678875, 9.161910299999999]       0.186135
# 45         [45.4678875, 9.161910299999999]       0.186135
# 46         [45.4678875, 9.161910299999999]       0.186135
# 47                 [45.4614957, 9.1851433]       0.360945
# 48  [45.43592899999999, 9.178215999999999]       0.821217
# 49                 [45.4865171, 9.2412476]      -0.057943
#
#     distanceToDangerZone  distanceToMedianJobLocation  zone  GreenConc  \
# 0               0.643889                     0.922359     9   1.000000
# 1               0.879735                     0.299515     9   1.000000
# 2               0.557633                     0.694444     2   0.487172
# 3               0.664893                     0.258368     1   0.658288
# 4               0.637378                     0.367297     7   0.970177
# 5               0.475489                     0.126140     1   0.658288
# 6               0.718022                     0.378781     7   0.970177
# 7               0.915819                     0.482037     3   0.698995
# 8               0.409005                     0.407334     6   0.667785
# 9               0.101734                     0.443413     5   0.335678
# 10              0.887727                     0.592908     2   0.487172
# 11              0.058130                     0.839039     9   1.000000
# 12              0.533388                     0.120515     1   0.658288
# 13              0.511982                     0.069959     1   0.658288
# 14              0.531460                     0.455804     5   0.335678
# 15              0.824802                     0.325333     1   0.658288
# 16              0.422280                     0.127182     1   0.658288
# 17              0.578320                     0.130905     1   0.658288
# 18              0.284033                     0.574690     6   0.667785
# 19              0.669546                     0.193032     1   0.658288
# 20              0.951619                     0.483115     3   0.698995
# 21              0.950486                     0.288188     9   1.000000
# 22              0.950486                     0.288188     9   1.000000
# 23              1.000000                     0.287430     9   1.000000
# 24              0.876898                     0.291686     1   0.658288
# 25              0.748747                     0.307802     8   0.859449
# 26              0.173490                     0.480262     5   0.335678
# 27              0.785834                     0.573815     2   0.487172
# 28              0.303044                     0.542258     5   0.335678
# 29              0.558039                     0.402534     7   0.970177
# 30              0.881017                     0.357568     3   0.698995
# 31              0.606116                     0.804521     2   0.487172
# 32              0.155624                     0.481603     5   0.335678
# 33              0.606116                     0.804521     2   0.487172
# 34              0.429543                     0.367369     7   0.970177
# 35              0.549851                     0.118275     1   0.658288
# 36              0.872140                     0.296825     8   0.859449
# 37              0.340825                     0.391028     6   0.667785
# 38              0.535337                     0.335244     7   0.970177
# 39              0.695307                     0.699347     4   0.584936
# 40              0.558039                     0.402534     7   0.970177
# 41              0.124020                     0.384551     5   0.335678
# 42              0.509342                     1.000000     8   0.859449
# 43              0.626948                     0.283968     7   0.970177
# 44              0.626948                     0.283968     7   0.970177
# 45              0.626948                     0.283968     7   0.970177
# 46              0.626948                     0.283968     7   0.970177
# 47              0.420871                     0.141038     1   0.658288
# 48              0.419174                     0.652583     5   0.335678
# 49              0.494538                     0.919745     3   0.698995
#
#     priceScaled      score
# 0       0.22500  15.624580
# 1       0.72500  15.998146
# 2       0.19500  10.132168
# 3       1.00000  14.976329
# 4       0.47500  12.950692
# 5       0.42500  10.200700
# 6       1.00000  16.090708
# 7       0.72900  15.901566
# 8       0.43750  10.408608
# 9       0.50000   9.535774
# 10      0.87500  15.741186
# 11      0.20000  15.485844
# 12      0.60000  11.301132
# 13      0.50000  10.070787
# 14      0.40000  12.384291
# 15      0.62500  14.071803
# 16      0.62500  10.899791
# 17      0.52075  10.655688
# 18      0.27500  11.717530
# 19      0.64625  11.991591
# 20      0.61250  14.927795
# 21      0.31250  14.154984
# 22      0.37500  14.467484
# 23      0.97500  17.618021
# 24      0.67500  14.060020
# 25      0.17750  11.499212
# 26      0.55000  10.695589
# 27      0.30000  11.783659
# 28      0.21250  10.728993
# 29      0.27500  11.617885
# 30      0.50000  14.046167
# 31      0.18750  11.620059
# 32      0.18750   8.627731
# 33      0.12500  11.307559
# 34      0.27500  11.031861
# 35      0.37250   9.736196
# 36      0.27500  12.902731
# 37      0.25000   9.238974
# 38      0.25000  11.234850
# 39      0.25000  14.031690
# 40      0.17500  11.117885
# 41      0.21250   7.914350
# 42      0.37500  18.254293
# 43      0.21000  11.386143
# 44      0.21000  11.386143
# 45      0.18500  11.261143
# 46      0.18500  11.261143
# 47      0.27500   9.280710
# 48      0.15000  11.893256
# 49      0.28875  11.720423

# %%
dfG = pd.read_pickle('data/dfGreen.pkl')
df.join(dfG.set_index('ZONADEC')['GreenConc'], on='zone')
# Out:
#                   id          type  \
# 0   link_ad_85188979      Bilocale
# 1   link_ad_63453592        Attico
# 2   link_ad_86792470      Bilocale
# 3   link_ad_86886580  Quadrilocale
# 4   link_ad_85281355     Trilocale
# 5   link_ad_82383218      Bilocale
# 6   link_ad_75892020  Appartamento
# 7   link_ad_86186172  Appartamento
# 8   link_ad_86197160     Trilocale
# 9   link_ad_86638504        Attico
# 10  link_ad_84406582         Villa
# 11  link_ad_85575130      Bilocale
# 12  link_ad_82947181      Bilocale
# 13  link_ad_85980992     Trilocale
# 14  link_ad_86309250      Bilocale
# 15  link_ad_79592117      Bilocale
# 16  link_ad_86433722     Trilocale
# 17  link_ad_87013428     Trilocale
# 18  link_ad_67133679      Bilocale
# 19  link_ad_85035204     Trilocale
# 20  link_ad_86725386     Trilocale
# 21  link_ad_53346343      Bilocale
# 22  link_ad_85003496      Bilocale
# 23  link_ad_80243683  Appartamento
# 24  link_ad_84956962     Trilocale
# 25  link_ad_87052168  Quadrilocale
# 26  link_ad_87045092      Bilocale
# 27  link_ad_87045088      Bilocale
# 28  link_ad_87052446     Trilocale
# 29  link_ad_87051670      Bilocale
# 30  link_ad_87045124    Monolocale
# 31  link_ad_87051600    Monolocale
# 32  link_ad_87052450      Bilocale
# 33  link_ad_87051650     Trilocale
# 34  link_ad_87052460     Trilocale
# 35  link_ad_87045094      Bilocale
# 36  link_ad_87045116      Bilocale
# 37  link_ad_87050632      Bilocale
# 38  link_ad_87052444      Bilocale
# 39  link_ad_87052620     Trilocale
# 40  link_ad_87045096      Bilocale
# 41  link_ad_87045118     Trilocale
# 42  link_ad_87045126    Monolocale
# 43  link_ad_87045108    Monolocale
# 44  link_ad_87045122    Monolocale
# 45  link_ad_87045100    Monolocale
# 46  link_ad_87045120      Bilocale
# 47  link_ad_87045104      Bilocale
# 48  link_ad_87045106    Monolocale
# 49  link_ad_87045084    Monolocale
#
#                                               address  price  \
# 0                  via Cozzi, Greco - Segnano, Milano    900
# 1   via Piero Maroncelli 5, Garibaldi - Corso Como...   2900
# 2               via Louis Pasteur 16, Pasteur, Milano    780
# 3      via Borgogna, Borgogna - Largo Augusto, Milano   4000
# 4                      via Elba 5, Washington, Milano   1900
# 5    piazza Santa Maria Beltrade 1, Carrobbio, Milano   1700
# 6                via Motta, Vercelli - Wagner, Milano   4000
# 7           via Giulio Uberti 9, Indipendenza, Milano   2916
# 8             via Amedeo Modigliani 4, Solari, Milano   1750
# 9          corso San Gottardo, Ascanio Sforza, Milano   2000
# 10  bifamiliare via Giuseppe Martucci 8, Maggiolin...   3500
# 11               via Enrico Cosenz 54, Bovisa, Milano    800
# 12                    ottimo stato, 11, Duomo, Milano   2400
# 13       corso Magenta 24, Cadorna - Castello, Milano   2000
# 14  via Altaguardia 11, Porta Romana - Medaglie d'...   1600
# 15         via Gaetano Donizetti 46, Palestro, Milano   2500
# 16             via San Maurilio 13, Carrobbio, Milano   2500
# 17       via Giacomo Leopardi, Vincenzo Monti, Milano   2083
# 18                   via Rimini 30, Famagosta, Milano   1100
# 19         via Vincenzo Monti, Vincenzo Monti, Milano   2585
# 20            via Francesco Redi 28, Morgagni, Milano   2450
# 21       corso Como 9, Garibaldi - Corso Como, Milano   1250
# 22       corso Como 9, Garibaldi - Corso Como, Milano   1500
# 23  piazzale Principessa Clotilde 8, Porta Nuova, ...   3900
# 24                corso Monforte 36, Palestro, Milano   2700
# 25       via Giuseppe Meda 16, Ascanio Sforza, Milano   2200
# 26                viale Lunigiana 7, Centrale, Milano   1200
# 27  via Francesco Brioschi 65, Pezzotti - Meda, Mi...    850
# 28      via Giorgio Washington 51, Washington, Milano   1100
# 29   via Pigello Portinari 2, Greco - Segnano, Milano    750
# 30  via Evangelista Torricelli 9, Ascanio Sforza, ...    750
# 31   via Pigello Portinari 2, Greco - Segnano, Milano    500
# 32           via Giuseppe Allegranza 7, Dezza, Milano   1100
# 33            piazza Virgilio, Vincenzo Monti, Milano   1490
# 34             via Marcello Pucci 6, Sempione, Milano   1100
# 35                     via Tortona 28, Solari, Milano   1000
# 36  via Coluccio Salutati 15, Vercelli - Wagner, M...   1000
# 37        via Lomellina 47, Argonne - Corsica, Milano   1000
# 38      via Giorgio Washington 51, Washington, Milano    700
# 39         corso Concordia, Piave - Tricolore, Milano   2000
# 40        via Gentilino 9, Corso San Gottardo, Milano    850
# 41             via Sem Benelli 8, Gallaratese, Milano   1500
# 42  via Giovanni Rasori 14, Vercelli - Wagner, Milano    840
# 43  via Giovanni Rasori 14, Vercelli - Wagner, Milano    840
# 44  via Giovanni Rasori 14, Vercelli - Wagner, Milano    740
# 45  via Giovanni Rasori 14, Vercelli - Wagner, Milano    740
# 46              via San Maurilio 1, Carrobbio, Milano   1100
# 47  via Stadera 18, Cermenate - Abbiategrasso, Milano    600
# 48            via Rombon 33, Quartiere Feltre, Milano   1155
# 49  via Giovanni Rasori 14, Vercelli - Wagner, Milano    740
#
#                                     coords  contamination  \
# 0                  [45.5092767, 9.2099263]       0.200892
# 1                   [45.4828706, 9.183481]       0.177840
# 2                  [45.4902223, 9.2193974]       0.055501
# 3                  [45.4636501, 9.1990135]       0.249087
# 4                  [45.4656953, 9.1562597]       0.084462
# 5          [45.4628843, 9.186818599999999]       0.213869
# 6                   [45.468491, 9.1552276]       0.091010
# 7                  [45.4696682, 9.2158532]       0.213412
# 8                  [45.4562768, 9.1586758]       0.096390
# 9                     [45.44644, 9.177026]       0.316888
# 10                  [45.495148, 9.1980762]       0.183891
# 11                 [45.5072367, 9.1622713]       0.602071
# 12                 [45.4643653, 9.1885593]       0.209542
# 13         [45.4662662, 9.177747799999999]       0.164925
# 14                 [45.4495176, 9.2001317]       0.453911
# 15                 [45.4669698, 9.2048192]       0.229351
# 16  [45.46197739999999, 9.184002699999999]       0.209044
# 17                   [45.468454, 9.172716]       0.146228
# 18          [45.44085219999999, 9.1703969]       0.326322
# 19                 [45.4710942, 9.1690085]       0.139200
# 20         [45.4767112, 9.213714099999999]       0.144094
# 21                 [45.4818759, 9.1871335]       0.168473
# 22                 [45.4818759, 9.1871335]       0.168473
# 23                 [45.4798228, 9.1933943]       0.157246
# 24          [45.471425, 9.201948999999999]       0.186721
# 25                 [45.4444426, 9.1788793]       0.361055
# 26                  [45.4910839, 9.205669]       0.126381
# 27         [45.4412943, 9.183195999999999]       0.452949
# 28                 [45.4613315, 9.1552382]       0.070940
# 29                  [45.502607, 9.2101814]       0.143716
# 30           [45.44455, 9.176829999999999]       0.340256
# 31                  [45.502607, 9.2101814]       0.143716
# 32         [45.4586115, 9.159839999999999]       0.098910
# 33                 [45.4675662, 9.1736272]       0.149509
# 34                 [45.4782924, 9.1668712]       0.166853
# 35                 [45.4551585, 9.1614421]       0.119305
# 36                 [45.4631496, 9.1593704]       0.094051
# 37                 [45.4625691, 9.2306147]       0.347244
# 38                 [45.4613315, 9.1552382]       0.070940
# 39         [45.4678939, 9.207147299999999]       0.223762
# 40                 [45.4490901, 9.1810181]       0.316763
# 41                 [45.4967547, 9.1244444]       0.546119
# 42         [45.4678875, 9.161910299999999]       0.112066
# 43         [45.4678875, 9.161910299999999]       0.112066
# 44         [45.4678875, 9.161910299999999]       0.112066
# 45         [45.4678875, 9.161910299999999]       0.112066
# 46                 [45.4614957, 9.1851433]       0.217314
# 47  [45.43592899999999, 9.178215999999999]       0.494431
# 48                 [45.4865171, 9.2412476]      -0.034886
# 49         [45.4678875, 9.161910299999999]       0.112066
#
#     distanceToDangerZone  distanceToMedianJobLocation  zone  GreenConc
# 0               2.351895                     5.072288     9   0.174133
# 1               3.213352                     1.647109     9   0.174133
# 2               2.036832                     3.818928     2   0.084833
# 3               2.428614                     1.420831     1   0.114630
# 4               2.328112                     2.019863     7   0.168940
# 5               1.736790                     0.693675     1   0.114630
# 6               2.622673                     2.083016     7   0.168940
# 7               3.345155                     2.650846     3   0.121718
# 8               1.493946                     2.240036     6   0.116283
# 9               0.371596                     2.438443     5   0.058453
# 10              3.242545                     3.260551     2   0.084833
# 11              0.212326                     4.614091     9   0.174133
# 12              1.948275                     0.662745     1   0.114630
# 13              1.870084                     0.384722     1   0.114630
# 14              1.941231                     2.506585     5   0.058453
# 15              3.012704                     1.789092     1   0.114630
# 16              1.542435                     0.699407     1   0.114630
# 17              2.112392                     0.719878     1   0.114630
# 18              1.037471                     3.160366     6   0.116283
# 19              2.445610                     1.061530     1   0.114630
# 20              3.475918                     2.656775     3   0.121718
# 21              3.471782                     1.584822     9   0.174133
# 22              3.471782                     1.584822     9   0.174133
# 23              3.652638                     1.580650     9   0.174133
# 24              3.202991                     1.604058     1   0.114630
# 25              0.633695                     2.641081     5   0.058453
# 26              2.870366                     3.155554     2   0.084833
# 27              1.106912                     2.982018     5   0.058453
# 28              2.038315                     2.213637     7   0.168940
# 29              2.213922                     4.424265     2   0.084833
# 30              0.568436                     2.648458     5   0.058453
# 31              2.213922                     4.424265     2   0.084833
# 32              1.568964                     2.020256     7   0.168940
# 33              2.008408                     0.650424     1   0.114630
# 34              3.185613                     1.632315     8   0.149659
# 35              1.244911                     2.150362     6   0.116283
# 36              1.955393                     1.843591     7   0.168940
# 37              2.539705                     3.845886     4   0.101857
# 38              2.038315                     2.213637     7   0.168940
# 39              3.218037                     1.966357     3   0.121718
# 40              0.452999                     2.114743     5   0.058453
# 41              1.860442                     5.499256     8   0.149659
# 42              2.290015                     1.561613     7   0.168940
# 43              2.290015                     1.561613     7   0.168940
# 44              2.290015                     1.561613     7   0.168940
# 45              2.290015                     1.561613     7   0.168940
# 46              1.537291                     0.775605     1   0.114630
# 47              1.531092                     3.588719     5   0.058453
# 48              1.806367                     5.057912     3   0.121718
# 49              2.290015                     1.561613     7   0.168940

# %%
def predictContamination(lt, lg, model):
    """ The function returns contamination values based on location
    Input:
    lt (float): latitude
    lg (float): longitude

    Output:
    Scaled contamaination value
    """
    pf = PolynomialFeatures(degree=3)
    return model.predict(pf.fit_transform([np.array([lt,lg])]))[0][0]

def generateContaminationModel(data):
    pf = PolynomialFeatures(degree=3)
    X = pf.fit_transform(data[["lt","lg"]])

    y = data[["normv"]]
    lr = LinearRegression()
    lr.fit(X,y)
    return lr

# %%
predictContamination(45.43,9.17,generateContaminationModel(df))
# Out:
# 0.5010502970253583

# %%
print(generateContaminationModel(df).coef_)
# Out:
# [[-1.84811346e-03 -5.49690763e+00  1.20524618e+01 -2.52431980e+02
#    2.48381631e+02  1.10711092e+02  4.04228511e+00 -4.65709075e+00
#   -5.98977581e+00  5.11241110e+00]]

# %%
# Out:
# ,

# %%
# Out:
# stazione_id,data,inquinante,valore
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     883             try:
# --> 884                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     885             except Exception:
#
# /opt/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /opt/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /opt/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-d53b6a6f03bb> in <module>
#       2 for l in f:
#       3     print(l. decode("utf-8"))
# ----> 4     input()
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     857             self._parent_ident,
#     858             self._parent_header,
# --> 859             password=False,
#     860         )
#     861
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     887             except KeyboardInterrupt:
#     888                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 889                 raise KeyboardInterrupt
#     890             else:
#     891                 break
#
# KeyboardInterrupt:

# %%
for station in dfAirRaw["stazione_id"].unique():
    fig, ax = plt.subplots(figsize=(20,10))
    ax = sns.barplot(x = dfAirRaw["data"].dt.strftime('%Y-%m-%d'), y = "normv",
                     data = dfAirRaw[dfAirRaw["stazione_id"] == station],
                     hue = "inquinante")
    plt.title(f"Station #{station}")
    ax.xaxis.set_major_locator(ticker.MaxNLocator())
